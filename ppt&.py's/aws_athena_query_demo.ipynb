# %%
"""
Topic: AWS Athena Basics (Querying S3 Data via SQL)
==================================================
Demonstrates how to run SQL queries on S3 data using Athena
via Python (boto3) and read results into pandas.
"""

import boto3
import time
import pandas as pd
import logging

# -------------------------------------------------------------------
# Step 1 – Initialize Athena and S3 Clients
# -------------------------------------------------------------------
athena = boto3.client("athena")
s3 = boto3.client("s3")

DATABASE = "supplychain_catalog"
OUTPUT_S3 = "s3://aws-athena-query-results-demo/"
QUERY = """
SELECT region, COUNT(*) AS delivered_shipments
FROM trusted_shipments
WHERE status = 'Delivered'
GROUP BY region
ORDER BY delivered_shipments DESC;
"""

logging.basicConfig(level=logging.INFO, format="%(asctime)s - %(message)s")
logger = logging.getLogger()

# -------------------------------------------------------------------
# Step 2 – Execute Athena Query
# -------------------------------------------------------------------
def run_athena_query(query, database, output_s3):
    logger.info("🚀 Starting Athena query...")
    response = athena.start_query_execution(
        QueryString=query,
        QueryExecutionContext={"Database": database},
        ResultConfiguration={"OutputLocation": output_s3}
    )
    execution_id = response["QueryExecutionId"]
    logger.info(f"🆔 Query Execution ID: {execution_id}")
    return execution_id

# -------------------------------------------------------------------
# Step 3 – Wait for Query Completion
# -------------------------------------------------------------------
def wait_for_query(execution_id):
    logger.info("⏳ Waiting for query to complete...")
    while True:
        status = athena.get_query_execution(QueryExecutionId=execution_id)
        state = status["QueryExecution"]["Status"]["State"]
        if state in ["SUCCEEDED", "FAILED", "CANCELLED"]:
            break
        time.sleep(2)
    logger.info(f"✅ Query State: {state}")
    if state != "SUCCEEDED":
        raise Exception(f"Query failed: {state}")

# -------------------------------------------------------------------
# Step 4 – Fetch Results from S3
# -------------------------------------------------------------------
def fetch_results(execution_id):
    logger.info("📥 Fetching query results...")
    result_response = athena.get_query_results(QueryExecutionId=execution_id)
    rows = result_response["ResultSet"]["Rows"]
    headers = [col["VarCharValue"] for col in rows[0]["Data"]]
    data = []
    for row in rows[1:]:
        values = [col.get("VarCharValue", None) for col in row["Data"]]
        data.append(values)
    df = pd.DataFrame(data, columns=headers)
    logger.info("✅ Query results loaded into DataFrame.")
    return df

# -------------------------------------------------------------------
# Step 5 – Main Execution Flow
# -------------------------------------------------------------------
def main():
    logger.info("🏁 Running Athena Demo Script")
    execution_id = run_athena_query(QUERY, DATABASE, OUTPUT_S3)
    wait_for_query(execution_id)
    df = fetch_results(execution_id)
    print("\n🎯 Query Output:")
    print(df)

if __name__ == "__main__":
    main()
# Out:
# ---------------------------------------------------------------------------
# NoRegionError                             Traceback (most recent call last)
# Cell In[1], line 16
#      11 import logging
#      13 # -------------------------------------------------------------------
#      14 # Step 1 – Initialize Athena and S3 Clients
#      15 # -------------------------------------------------------------------
# ---> 16 athena = boto3.client("athena")
#      17 s3 = boto3.client("s3")
#      19 DATABASE = "supplychain_catalog"
#
# File ~\anaconda3\lib\site-packages\boto3\__init__.py:92, in client(*args, **kwargs)
#      86 def client(*args, **kwargs):
#      87     """
#      88     Create a low-level service client by name using the default session.
#      89
#      90     See :py:meth:`boto3.session.Session.client`.
#      91     """
# ---> 92     return _get_default_session().client(*args, **kwargs)
#
# File ~\anaconda3\lib\site-packages\boto3\session.py:322, in Session.client(self, service_name, region_name, api_version, use_ssl, verify, endpoint_url, aws_access_key_id, aws_secret_access_key, aws_session_token, config, aws_account_id)
#     235 def client(
#     236     self,
#     237     service_name,
#    (...)
#     247     aws_account_id=None,
#     248 ):
#     249     """
#     250     Create a low-level service client by name.
#     251
#    (...)
#     320
#     321     """
# --> 322     return self._session.create_client(
#     323         service_name,
#     324         region_name=region_name,
#     325         api_version=api_version,
#     326         use_ssl=use_ssl,
#     327         verify=verify,
#     328         endpoint_url=endpoint_url,
#     329         aws_access_key_id=aws_access_key_id,
#     330         aws_secret_access_key=aws_secret_access_key,
#     331         aws_session_token=aws_session_token,
#     332         config=config,
#     333         aws_account_id=aws_account_id,
#     334     )
#
# File ~\anaconda3\lib\site-packages\botocore\context.py:123, in with_current_context.<locals>.decorator.<locals>.wrapper(*args, **kwargs)
#     121 if hook:
#     122     hook()
# --> 123 return func(*args, **kwargs)
#
# File ~\anaconda3\lib\site-packages\botocore\session.py:1019, in Session.create_client(self, service_name, region_name, api_version, use_ssl, verify, endpoint_url, aws_access_key_id, aws_secret_access_key, aws_session_token, config, aws_account_id)
#    1005 user_agent_creator.set_client_features(get_context().features)
#    1007 client_creator = botocore.client.ClientCreator(
#    1008     loader,
#    1009     endpoint_resolver,
#    (...)
#    1017     user_agent_creator=user_agent_creator,
#    1018 )
# -> 1019 client = client_creator.create_client(
#    1020     service_name=service_name,
#    1021     region_name=region_name,
#    1022     is_secure=use_ssl,
#    1023     endpoint_url=endpoint_url,
#    1024     verify=verify,
#    1025     credentials=credentials,
#    1026     scoped_config=self.get_scoped_config(),
#    1027     client_config=config,
#    1028     api_version=api_version,
#    1029     auth_token=auth_token,
#    1030 )
#    1031 monitor = self._get_internal_component('monitor')
#    1032 if monitor is not None:
#
# File ~\anaconda3\lib\site-packages\botocore\client.py:166, in ClientCreator.create_client(self, service_name, region_name, is_secure, endpoint_url, verify, credentials, scoped_config, api_version, client_config, auth_token)
#     155     service_signature_version = service_model.metadata.get(
#     156         'signatureVersion'
#     157     )
#     158 endpoint_bridge = ClientEndpointBridge(
#     159     self._endpoint_resolver,
#     160     scoped_config,
#    (...)
#     164     service_signature_version=service_signature_version,
#     165 )
# --> 166 client_args = self._get_client_args(
#     167     service_model,
#     168     region_name,
#     169     is_secure,
#     170     endpoint_url,
#     171     verify,
#     172     credentials,
#     173     scoped_config,
#     174     client_config,
#     175     endpoint_bridge,
#     176     auth_token,
#     177     endpoints_ruleset_data,
#     178     partition_data,
#     179 )
#     180 service_client = cls(**client_args)
#     181 self._register_retries(service_client)
#
# File ~\anaconda3\lib\site-packages\botocore\client.py:525, in ClientCreator._get_client_args(self, service_model, region_name, is_secure, endpoint_url, verify, credentials, scoped_config, client_config, endpoint_bridge, auth_token, endpoints_ruleset_data, partition_data)
#     501 def _get_client_args(
#     502     self,
#     503     service_model,
#    (...)
#     514     partition_data,
#     515 ):
#     516     args_creator = ClientArgsCreator(
#     517         self._event_emitter,
#     518         self._user_agent,
#    (...)
#     523         user_agent_creator=self._user_agent_creator,
#     524     )
# --> 525     return args_creator.get_client_args(
#     526         service_model,
#     527         region_name,
#     528         is_secure,
#     529         endpoint_url,
#     530         verify,
#     531         credentials,
#     532         scoped_config,
#     533         client_config,
#     534         endpoint_bridge,
#     535         auth_token,
#     536         endpoints_ruleset_data,
#     537         partition_data,
#     538     )
#
# File ~\anaconda3\lib\site-packages\botocore\args.py:125, in ClientArgsCreator.get_client_args(self, service_model, region_name, is_secure, endpoint_url, verify, credentials, scoped_config, client_config, endpoint_bridge, auth_token, endpoints_ruleset_data, partition_data)
#     110 def get_client_args(
#     111     self,
#     112     service_model,
#    (...)
#     123     partition_data=None,
#     124 ):
# --> 125     final_args = self.compute_client_args(
#     126         service_model,
#     127         client_config,
#     128         endpoint_bridge,
#     129         region_name,
#     130         endpoint_url,
#     131         is_secure,
#     132         scoped_config,
#     133     )
#     135     service_name = final_args['service_name']  # noqa
#     136     parameter_validation = final_args['parameter_validation']
#
# File ~\anaconda3\lib\site-packages\botocore\args.py:249, in ClientArgsCreator.compute_client_args(self, service_model, client_config, endpoint_bridge, region_name, endpoint_url, is_secure, scoped_config)
#     246 if configured_endpoint_url is not None:
#     247     register_feature_id('ENDPOINT_OVERRIDE')
# --> 249 endpoint_config = self._compute_endpoint_config(
#     250     service_name=service_name,
#     251     region_name=region_name,
#     252     endpoint_url=configured_endpoint_url,
#     253     is_secure=is_secure,
#     254     endpoint_bridge=endpoint_bridge,
#     255     s3_config=s3_config,
#     256 )
#     257 endpoint_variant_tags = endpoint_config['metadata'].get('tags', [])
#     259 # Some third-party libraries expect the final user-agent string in
#     260 # ``client.meta.config.user_agent``. To maintain backwards
#     261 # compatibility, the preliminary user-agent string (before any Config
#     262 # object modifications and without request-specific user-agent
#     263 # components) is stored in the new Config object's ``user_agent``
#     264 # property but not used by Botocore itself.
#
# File ~\anaconda3\lib\site-packages\botocore\args.py:432, in ClientArgsCreator._compute_endpoint_config(self, service_name, region_name, endpoint_url, is_secure, endpoint_bridge, s3_config)
#     430 if service_name == 'sts':
#     431     return self._compute_sts_endpoint_config(**resolve_endpoint_kwargs)
# --> 432 return self._resolve_endpoint(**resolve_endpoint_kwargs)
#
# File ~\anaconda3\lib\site-packages\botocore\args.py:537, in ClientArgsCreator._resolve_endpoint(self, service_name, region_name, endpoint_url, is_secure, endpoint_bridge)
#     529 def _resolve_endpoint(
#     530     self,
#     531     service_name,
#    (...)
#     535     endpoint_bridge,
#     536 ):
# --> 537     return endpoint_bridge.resolve(
#     538         service_name, region_name, endpoint_url, is_secure
#     539     )
#
# File ~\anaconda3\lib\site-packages\botocore\client.py:630, in ClientEndpointBridge.resolve(self, service_name, region_name, endpoint_url, is_secure)
#     624 use_dualstack_endpoint = self._resolve_use_dualstack_endpoint(
#     625     service_name
#     626 )
#     627 use_fips_endpoint = self._resolve_endpoint_variant_config_var(
#     628     'use_fips_endpoint'
#     629 )
# --> 630 resolved = self.endpoint_resolver.construct_endpoint(
#     631     service_name,
#     632     region_name,
#     633     use_dualstack_endpoint=use_dualstack_endpoint,
#     634     use_fips_endpoint=use_fips_endpoint,
#     635 )
#     637 # If we can't resolve the region, we'll attempt to get a global
#     638 # endpoint for non-regionalized services (iam, route53, etc)
#     639 if not resolved:
#     640     # TODO: fallback partition_name should be configurable in the
#     641     # future for users to define as needed.
#
# File ~\anaconda3\lib\site-packages\botocore\regions.py:232, in EndpointResolver.construct_endpoint(self, service_name, region_name, partition_name, use_dualstack_endpoint, use_fips_endpoint)
#     227 if use_dualstack_endpoint and (
#     228     partition['partition']
#     229     in self._UNSUPPORTED_DUALSTACK_PARTITIONS
#     230 ):
#     231     continue
# --> 232 result = self._endpoint_for_partition(
#     233     partition,
#     234     service_name,
#     235     region_name,
#     236     use_dualstack_endpoint,
#     237     use_fips_endpoint,
#     238 )
#     239 if result:
#     240     return result
#
# File ~\anaconda3\lib\site-packages\botocore\regions.py:280, in EndpointResolver._endpoint_for_partition(self, partition, service_name, region_name, use_dualstack_endpoint, use_fips_endpoint, force_partition)
#     278         region_name = service_data['partitionEndpoint']
#     279     else:
# --> 280         raise NoRegionError()
#     282 resolve_kwargs = {
#     283     'partition': partition,
#     284     'service_name': service_name,
#    (...)
#     288     'use_fips_endpoint': use_fips_endpoint,
#     289 }
#     291 # Attempt to resolve the exact region for this partition.
#
# NoRegionError: You must specify a region.
