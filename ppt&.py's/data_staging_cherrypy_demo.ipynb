# %%
# !pip install CherryPy
# Out:
# Requirement already satisfied: CherryPy in c:\users\hp\anaconda3\lib\site-packages (18.10.0)
# Requirement already satisfied: jaraco.collections in c:\users\hp\anaconda3\lib\site-packages (from CherryPy) (5.2.1)
# Requirement already satisfied: portend>=2.1.1 in c:\users\hp\anaconda3\lib\site-packages (from CherryPy) (3.2.1)
# Requirement already satisfied: zc.lockfile in c:\users\hp\anaconda3\lib\site-packages (from CherryPy) (4.0)
# Requirement already satisfied: cheroot>=8.2.1 in c:\users\hp\anaconda3\lib\site-packages (from CherryPy) (11.1.2)
# Requirement already satisfied: more-itertools in c:\users\hp\anaconda3\lib\site-packages (from CherryPy) (10.8.0)
# Requirement already satisfied: jaraco.functools in c:\users\hp\anaconda3\lib\site-packages (from cheroot>=8.2.1->CherryPy) (4.3.0)
# Requirement already satisfied: tempora>=1.8 in c:\users\hp\anaconda3\lib\site-packages (from portend>=2.1.1->CherryPy) (5.8.1)
# Requirement already satisfied: jaraco.text in c:\users\hp\anaconda3\lib\site-packages (from jaraco.collections->CherryPy) (4.0.0)
# Requirement already satisfied: setuptools in c:\users\hp\anaconda3\lib\site-packages (from zc.lockfile->CherryPy) (65.6.3)
# Requirement already satisfied: python-dateutil in c:\users\hp\anaconda3\lib\site-packages (from tempora>=1.8->portend>=2.1.1->CherryPy) (2.8.2)
# Requirement already satisfied: autocommand in c:\users\hp\anaconda3\lib\site-packages (from jaraco.text->jaraco.collections->CherryPy) (2.2.2)
# Requirement already satisfied: jaraco.context>=4.1 in c:\users\hp\anaconda3\lib\site-packages (from jaraco.text->jaraco.collections->CherryPy) (6.0.1)
# Requirement already satisfied: backports.tarfile in c:\users\hp\anaconda3\lib\site-packages (from jaraco.context>=4.1->jaraco.text->jaraco.collections->CherryPy) (1.2.0)
# Requirement already satisfied: six>=1.5 in c:\users\hp\anaconda3\lib\site-packages (from python-dateutil->tempora>=1.8->portend>=2.1.1->CherryPy) (1.16.0)

# %%
"""
Example 1: Basic CherryPy CSV Generator
---------------------------------------
Creates a simple CherryPy web server that returns a CSV
of sample employee data.
"""

import cherrypy
import csv
import io

class CSVServer:
    @cherrypy.expose
    def index(self):
        data = [
            ["EmployeeID", "Name", "Role"],
            [1, "Ravi", "Analyst"],
            [2, "Asha", "Engineer"],
            [3, "Kiran", "Manager"]
        ]

        buffer = io.StringIO()
        writer = csv.writer(buffer)
        writer.writerows(data)

        cherrypy.response.headers['Content-Type'] = 'text/csv'
        cherrypy.response.headers['Content-Disposition'] = 'attachment; filename="employees.csv"'
        return buffer.getvalue()

if __name__ == '__main__':
    cherrypy.quickstart(CSVServer())
# Out:
# [12/Nov/2025:14:52:16] ENGINE Listening for SIGTERM.
# [12/Nov/2025:14:52:16] ENGINE Bus STARTING
# CherryPy Checker:
# The Application mounted at '' has an empty config.
#
# [12/Nov/2025:14:52:16] ENGINE Set handler for console events.
# [12/Nov/2025:14:52:16] ENGINE Started monitor thread 'Autoreloader'.
# [12/Nov/2025:14:52:16] ENGINE Serving on http://127.0.0.1:8080
# [12/Nov/2025:14:52:16] ENGINE Bus STARTED

# %%
"""
Example 2: CherryPy CSV with Token Authentication
-------------------------------------------------
Adds secure token-based access to the CSV generation API.
"""

import cherrypy
import csv
import io
import secrets

# Generate a random token
ACCESS_TOKEN = secrets.token_hex(8)
print(f"Your access token: {ACCESS_TOKEN}")

class SecureCSVServer:
    @cherrypy.expose
    def generate(self, token=None):
        if token != ACCESS_TOKEN:
            raise cherrypy.HTTPError(401, "Unauthorized access - Invalid token")

        data = [
            ["OrderID", "Product", "Quantity", "Region"],
            [1001, "Laptop", 5, "APAC"],
            [1002, "Tablet", 10, "EMEA"],
            [1003, "Phone", 15, "US"]
        ]

        buffer = io.StringIO()
        writer = csv.writer(buffer)
        writer.writerows(data)

        cherrypy.response.headers['Content-Type'] = 'text/csv'
        cherrypy.response.headers['Content-Disposition'] = 'attachment; filename="orders.csv"'
        return buffer.getvalue()

if __name__ == '__main__':
    cherrypy.quickstart(SecureCSVServer())
